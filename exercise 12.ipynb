# %% [markdown]
# Crea un dataframe di dieci righe, quattro colonne con valori casuali. Converti alcuni valori in valori nan. Scrivi un programma Panda che evidenzi i valori nan.

# %%
import pandas as pd
import numpy as np

Impiegati = pd.DataFrame({
    "nome" : ["Marta", "Marco", "Manuela", "Luca", "Carla", "Gianni", np.nan, "Giulia", "Alba", np.nan, "Valerio"],
    "ID" : [12, 56, np.nan, 45, 67, 75, 32, 54, 99, 64, 46],
    "età" : [25, 29, 30, 31, 24, 26, np.nan, 24, 32, 34, 28],
    "laurea": ["si", np.nan, "si", "si", "si", "no", "no", np.nan, "si", "no", "si"]})

Impiegati
# Out:
#        nome    ID   età laurea
# 0     Marta  12.0  25.0     si
# 1     Marco  56.0  29.0    NaN
# 2   Manuela   NaN  30.0     si
# 3      Luca  45.0  31.0     si
# 4     Carla  67.0  24.0     si
# 5    Gianni  75.0  26.0     no
# 6       NaN  32.0   NaN     no
# 7    Giulia  54.0  24.0    NaN
# 8      Alba  99.0  32.0     si
# 9       NaN  64.0  34.0     no
# 10  Valerio  46.0  28.0     si

# %%
Impiegati.isnull()
# Out:
#      nome     ID    età  laurea
# 0   False  False  False   False
# 1   False  False  False    True
# 2   False   True  False   False
# 3   False  False  False   False
# 4   False  False  False   False
# 5   False  False  False   False
# 6    True  False   True   False
# 7   False  False  False    True
# 8   False  False  False   False
# 9    True  False  False   False
# 10  False  False  False   False

# %%
Impiegati.style.highlight_null('red')
# Out:
# <style type="text/css">
# #T_4f3d3_row1_col3, #T_4f3d3_row2_col1, #T_4f3d3_row6_col0, #T_4f3d3_row6_col2, #T_4f3d3_row7_col3, #T_4f3d3_row9_col0 {
#   background-color: red;
# }
# </style>
# <table id="T_4f3d3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f3d3_level0_col0" class="col_heading level0 col0" >nome</th>
#       <th id="T_4f3d3_level0_col1" class="col_heading level0 col1" >ID</th>
#       <th id="T_4f3d3_level0_col2" class="col_heading level0 col2" >età</th>
#       <th id="T_4f3d3_level0_col3" class="col_heading level0 col3" >laurea</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f3d3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4f3d3_row0_col0" class="data row0 col0" >Marta</td>
#       <td id="T_4f3d3_row0_col1" class="data row0 col1" >12.000000</td>
#       <td id="T_4f3d3_row0_col2" class="data row0 col2" >25.000000</td>
# ...
