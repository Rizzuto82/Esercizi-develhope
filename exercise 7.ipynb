# %% [markdown]
# Scrivere un programma Panda per filtrare i record dal set di dati sul consumo mondiale di alcol in cui l'aspettativa di vita è superiore all'aspettativa di vita media di tutti i paesi. Recupera il Paese, l'aspettativa di vita e il PIL pro capite per questi record filtrati.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("C:\\Users\\rizzu\\OneDrive\\Desktop\\visual studio\\esercizi piattaforma numpy pandas\\World_Alcohol_Dataset - MAIN.csv", na_values = "?")
print(df)
# Out:
#                  country  beer_servings  spirit_servings  wine_servings  \
# 0            Afghanistan            0.0              0.0            0.0
# 1                Albania           89.0            132.0           54.0
# 2                Algeria           25.0              0.0           14.0
# 3                 Angola          217.0             57.0           45.0
# 4    Antigua and Barbuda          102.0            128.0           45.0
# ..                   ...            ...              ...            ...
# 172            Venezuela          333.0            100.0            3.0
# 173              Vietnam          111.0              2.0            1.0
# 174                Yemen            6.0              0.0            0.0
# 175               Zambia           32.0             19.0            4.0
# 176             Zimbabwe           64.0             18.0            4.0
#
#      life_expentancy                region  gdp_per_capita
# ...

# %%
df["life_expentancy"].mean()
# Out:
# 71.67909604519774

# %%
df[(df["life_expentancy"] > df["life_expentancy"].mean())]
# Out:
#                  country  beer_servings  spirit_servings  wine_servings  \
# 1                Albania           89.0            132.0           54.0
# 2                Algeria           25.0              0.0           14.0
# 4    Antigua and Barbuda          102.0            128.0           45.0
# 5              Argentina          193.0             25.0          221.0
# 6                Armenia           21.0            179.0           11.0
# ..                   ...            ...              ...            ...
# 168              Uruguay          115.0             35.0          220.0
# 169                  USA          249.0            158.0           84.0
# 171              Vanuatu           21.0             18.0           11.0
# 172            Venezuela          333.0            100.0            3.0
# 173              Vietnam          111.0              2.0            1.0
#
#      life_expentancy                region  gdp_per_capita
# ...

# %%
dff= df[["country", "life_expentancy", "gdp_per_capita"]].sort_values(by=("life_expentancy"),ascending=False)
dff.head(30)
# Out:
#             country  life_expentancy  gdp_per_capita
# 141        Slovenia             88.0           19000
# 44          Denmark             86.0           31100
# 33            Chile             85.0            9900
# 42           Cyprus             85.0           19200
# 81            Japan             83.7           28200
# 152     Switzerland             83.4           32700
# 139       Singapore             83.1           23700
# 146           Spain             82.8           22000
# 7         Australia             82.8           29000
# 72          Iceland             82.7           30900
# 79            Italy             82.7           26700
# 78           Israel             82.5           19800
# 151          Sweden             82.4           26800
# 57           France             82.4           27600
# 145     South Korea             82.3           17800
# 30           Canada             82.2           29800
# 95       Luxembourg             82.0           55100
# ...
